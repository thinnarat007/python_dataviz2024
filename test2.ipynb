# %% [markdown]
# <a href="https://colab.research.google.com/github/thinnarat007/python_dataviz2024/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/Data_viz2024_Data/Test/test 2'

# %%
person = os.path.join(path,'person.csv')
interview = os.path.join(path,'interview.csv')
income = os.path.join(path,'income.csv')
get_fit_now_member = os.path.join(path,'get_fit_now_member.csv')
get_fit_now_check_in = os.path.join(path,'get_fit_now_check_in.csv')
drivers_license = os.path.join(path,'drivers_license.csv')
facebook_event_checkin = os.path.join(path,'facebook_event_checkin.csv')
crime_scene_report = os.path.join(path,'crime_scene_report.csv')

# %%
person_df = pd.read_csv(person)
person_df.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
crime_scene_report_df = pd.read_csv(crime_scene_report)
crime_scene_report_df.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
print(crime_scene_report_df.dtypes)
# Out:
# date            int64
# type           object
# description    object
# city           object
# dtype: object

# %%
# แปลงจาก int เป็น date
crime_scene_report_df['date'] = pd.to_datetime(crime_scene_report_df['date'], format='%Y%m%d', errors='coerce')

# %%
print(crime_scene_report_df.dtypes)
# Out:
# date           datetime64[ns]
# type                   object
# description            object
# city                   object
# dtype: object

# %%
crime_scene_report_df
# Out:
#            date     type                                        description  \
# 0    2018-01-15  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1    2018-01-15   murder                  Life? Dont talk to me about life.
# 2    2018-01-15   murder  Mama, I killed a man, put a gun against his he...
# 3    2018-02-15   murder                         REDACTED REDACTED REDACTED
# 4    2018-02-15   murder  Someone killed the guard! He took an arrow to ...
# ...         ...      ...                                                ...
# 1223 2018-04-30  bribery                                                 \n
# 1224 2018-04-30    fraud                  ‘Why not?’ said the March Hare.\n
# 1225 2018-04-30  assault                                                 \n
# 1226 2018-05-01  assault  be NO mistake about it: it was neither more no...
# 1227 2018-01-15   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# ...

# %%
murder_case_sql_city_df = crime_scene_report_df[
    (crime_scene_report_df['date'] == '2018-01-15') &
    (crime_scene_report_df['city'] == 'SQL City') &
    (crime_scene_report_df['type'] == 'murder')
]

# แสดงผลข้อมูลที่กรองได้
murder_case_sql_city_df
# Out:
#            date    type                                        description  \
# 1227 2018-01-15  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %% [markdown]
# ภาพจากกล้องวงจรปิดพบว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบน "Northwestern Dr" พยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบนถนนแฟรงคลิน

# %%
person_df
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
# กรองข้อมูลเพื่อค้นหาบุคคลที่อาศัยอยู่บนถนน Northwestern Dr
northwestern_residents = person_df[person_df['address_street_name'].str.contains('Northwestern Dr')]

# %%
northwestern_residents['address_number'] = northwestern_residents['address_number'].astype(int)
last_house_northwestern = northwestern_residents.loc[northwestern_residents['address_number'].idxmax()]
print(last_house_northwestern) #พยานคนแรก
# Out:
# id                               14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# Name: 499, dtype: object
# <ipython-input-15-ee193042748a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northwestern_residents['address_number'] = northwestern_residents['address_number'].astype(int)

# %%
# กรองข้อมูลเพื่อค้นหาบุคคลที่ชื่อ Annabel และอาศัยอยู่ที่ถนน Franklin
annabel_franklin = person_df[
    (person_df['name'].str.contains('Annabel', case=False, na=False)) &
    (person_df['address_street_name'].str.contains('Franklin', case=False, na=False))]

# แสดงผลข้อมูลที่กรองได้
annabel_franklin #พยานคนสอง
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
interview_df = pd.read_csv(interview) #interview #หาคำของพยาน
interview_df
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
# กรองข้อมูล id สำหรับ 16371 และ 14887 ในตาราง interview_df
filtered_interview = interview_df[interview_df['person_id'].isin([16371, 14887])]

# แสดงผลลัพธ์
print(filtered_interview) #คำให้การของพยานทั้งสองคน
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
# แสดง transcript ทั้งหมดจากตาราง filtered_interview
for index, row in filtered_interview.iterrows():
    print(row['transcript'])
# Out:
# I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# ฉันได้ยินเสียงปืนแล้วก็เห็นชายคนหนึ่งวิ่งออกไป เขามีกระเป๋า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z" เฉพาะสมาชิกระดับโกลด์เท่านั้นที่มีถุงเหล่านั้น ชายคนนั้นขึ้นรถพร้อมจานที่มี "H42W"
# ฉันเห็นการฆาตกรรมเกิดขึ้น และฉันก็จำฆาตกรได้จากยิมของฉันตอนที่ฉันกำลังออกกำลังกายเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม

# %%
get_fit_now_member = os.path.join(path,'get_fit_now_member.csv')
get_fit_now_check_in = os.path.join(path,'get_fit_now_check_in.csv')

# %%
check_in_df = pd.read_csv(get_fit_now_check_in) #หาคนที่เข้ายิมวันที่ 15
member = pd.read_csv(get_fit_now_member)

# %%
check_in_df.head() #คนที่เข้ายิมวันที่ 15
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
check_in_df['check_in_date'] = pd.to_datetime(check_in_df['check_in_date'], format='%Y%m%d', errors='coerce') #แปลงเป็นวันที่

# %%
# กรองข้อมูลเฉพาะวันที่ 15 มกราคม 2018
check_in_jan15 = check_in_df[check_in_df['check_in_date'] == '2018-01-15']

# %%
check_in_jan15.head() #คนที่เข้าใช้ฟิตในวันเกิดเหตุการณ์
# Out:
#      membership_id check_in_date  check_in_time  check_out_time
# 680          D2KY6    2018-01-15            746             836
# 1553         344VM    2018-01-15           1087            1195
# 2347         3BRSC    2018-01-15            354             825
# 2649         HM6U8    2018-01-15            525             800

# %%
member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
member['membership_start_date'] = pd.to_datetime(member['membership_start_date'], format='%Y%m%d', errors='coerce') #แปลงข้อมูล
member
# Out:
#         id  person_id                name membership_start_date  \
# 0    NL318      65076     Everette Koepke            2017-09-26
# 1    AOE21      39426        Noe Locascio            2017-10-05
# 2    2PN28      63823  Jeromy Heitschmidt            2018-02-15
# 3    0YJ24      80651      Waneta Wellard            2017-12-06
# 4    3A08L      32858        Mei Bianchin            2017-04-01
# ..     ...        ...                 ...                   ...
# 179  2V137      41693      Wendell Dulany            2017-12-19
# 180  4KB72      79110          Emile Hege            2017-05-22
# 181  48Z7A      28819        Joe Germuska            2016-03-05
# 182  48Z55      67318       Jeremy Bowers            2016-01-01
# 183  90081      16371      Annabel Miller            2016-02-08
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# 179            silver
# ...

# %%
 # กรองข้อมูลตามหลาย ID โดยตรง
member15 = member[member['id'].isin(['344VM', 'HM6U8', '3BRSC', 'D2KY6'])]

# %%
member15 # หาคนที่ใช้ ฟิตเนส วันเกิดเหตุ
# Out:
#         id  person_id              name membership_start_date  \
# 55   D2KY6      99602  Joline Hollering            2017-02-20
# 110  344VM      13466      Armando Huie            2017-10-02
# 158  3BRSC      19948      Taylor Skyes            2018-03-14
# 178  HM6U8      50106       Edgar Bamba            2017-01-28
#
#     membership_status
# 55               gold
# 110           regular
# 158              gold
# 178            silver

# %% [markdown]
# จากคำให้การณ์ของพยานคนแรกบอกว่า ฉันได้ยินเสียงปืนแล้วก็เห็นชายคนหนึ่งวิ่งออกไป เขามีกระเป๋า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z" เฉพาะสมาชิกระดับโกลด์เท่านั้นที่มีถุงเหล่านั้น ชายคนนั้นขึ้นรถพร้อมทะเบียนที่มี "H42W"  แต่จากที่ดูข้อมูลคนที่ใช้ยิมวันที่ 15 มกราคม 2018 ไม่มี หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z แต่มี ระดับโกลด์สองคน

# %%
# กรองข้อมูลสมาชิกยิมที่ id ขึ้นต้นด้วย 48Z
filtered_members48Z = member[member['id'].str.startswith('48Z')]

# แสดงผลลัพธ์
print(filtered_members48Z)  #ข้อมูลสมาชิกยิมที่ id ขึ้นต้นด้วย 48Z
# Out:
#         id  person_id           name membership_start_date membership_status
# 154  48Z38      49550  Tomas Baisley            2017-02-03            silver
# 181  48Z7A      28819   Joe Germuska            2016-03-05              gold
# 182  48Z55      67318  Jeremy Bowers            2016-01-01              gold

# %%
person_df.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
print(person_df[person_df['id'] == 49550]) #คนนี้อยู่  silver
# Out:
#          id           name  license_id  address_number address_street_name  \
# 4411  49550  Tomas Baisley      309485            2050        Lamplight St
#
#             ssn
# 4411  851169893

# %%
print(person_df[person_df['id'] == 28819])
# Out:
#          id          name  license_id  address_number address_street_name  \
# 2037  28819  Joe Germuska      173289             111             Fisk Rd
#
#             ssn
# 2037  138909730

# %%
print(person_df[person_df['id'] == 67318])
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %%
driver_license_df = pd.read_csv(drivers_license)
driver_license_df.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
# สำหรับ ID 423327
driver_423327 = driver_license_df[driver_license_df['id'] == 423327]
driver_423327
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#      car_model
# 3529  Spark LS

# %% [markdown]
# จากตรงนี้เราได้ชายปริศนที่ มีรหัสสมาชิกยิมขึ้นต้นด้ย 48Z และจาก ข้อมูลใบขับขี่ ทะเบียนรถของเขามี H42W2 ตามที่พยานคนแรกบอก

# %%
# สำหรับ ID 173289
driver_173289 = driver_license_df[driver_license_df['id'] == 173289]

# %%
driver_173289
# Out:
# Empty DataFrame
# Columns: [id, age, height, eye_color, hair_color, gender, plate_number, car_make, car_model]
# Index: []

# %% [markdown]
# พยานคนที่สองบอกว่า ฉันเห็นการฆาตกรรมเกิดขึ้น และฉันก็จำฆาตกรได้จากยิมของฉันตอนที่ฉันกำลังออกกำลังกายเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม

# %%
# กรองข้อมูลเฉพาะวันที่ 09 มกราคม 2018
check_in_jan09 = check_in_df[check_in_df['check_in_date'] == '2018-01-09']

# %%
check_in_jan09
# Out:
#      membership_id check_in_date  check_in_time  check_out_time
# 113          X0643    2018-01-09            957            1164
# 889          UK1F2    2018-01-09            344             518
# 1329         XTE42    2018-01-09            486            1124
# 1446         1AE2H    2018-01-09            461             944
# 1703         6LSTG    2018-01-09            399             515
# 2137         7MWHJ    2018-01-09            273             885
# 2435         GE5Q8    2018-01-09            367             959
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700
# 2702         90081    2018-01-09           1600            1700

# %%
#จากพยานคนแรกบอกว่าเขาสะพานกระเป๋าที่มีรหัสสมาชิกยิมขึ้นต้นด้วย 48Z ขึ้นรถที่มีทะเบียน H42W และ membership_id ที่ใช้ยิมวันที่ 9 ที่พยานคนที่สองบอก มี 1 คนที่มีทุกอย่างครบตามพยานบอก
#Jeremy Bowers
 # กรองข้อมูลตามหลาย ID โดยตรง

# %%
# #หาทะเบียนรถ H42W
filtered_licenses = driver_license_df[driver_license_df['plate_number'].str.contains('H42W')]

# Display the filtered results
filtered_licenses
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
#หา id 51739 67318 78193 interview_df
interview_df[interview_df['person_id'].isin([51739, 67318, 78193])]
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
person_df[person_df['id'].isin([67318])]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %% [markdown]
# ฉันถูกจ้างโดยผู้หญิงที่มีเงินมากมาย ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5'5" (65") หรือ 5'7" (67") เธอมีผมสีแดงและเธอขับรถ Tesla Model S ฉันรู้ว่าเธอเข้าร่วม SQL Symphony Concert 3 ครั้งในเดือนธันวาคม 2017

# %%
facebook_event_checkin_df = pd.read_csv(facebook_event_checkin)
facebook_event_checkin_df.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %%
# แปลงคอลัมน์ 'date' เป็น datetime
facebook_event_checkin_df['date'] = pd.to_datetime(facebook_event_checkin_df['date'], format='%Y%m%d', errors='coerce')

# กรองข้อมูลสำหรับ 'SQL Symphony Concert' ในเดือนธันวาคม 2017
filtered_events = facebook_event_checkin_df[
    (facebook_event_checkin_df['event_name'] == 'SQL Symphony Concert') &
    (facebook_event_checkin_df['date'].dt.month == 12) &
    (facebook_event_checkin_df['date'].dt.year == 2017)
]

# แสดงผลลัพธ์
print(filtered_events)
# Out:
#        person_id  event_id            event_name       date
# 4087       62596      1143  SQL Symphony Concert 2017-12-25
# 4392       19260      1143  SQL Symphony Concert 2017-12-14
# 6552       58898      1143  SQL Symphony Concert 2017-12-20
# 6620       69699      1143  SQL Symphony Concert 2017-12-14
# 6717       19292      1143  SQL Symphony Concert 2017-12-13
# 7266       43366      1143  SQL Symphony Concert 2017-12-07
# 8395       92343      1143  SQL Symphony Concert 2017-12-12
# 10909      28582      1143  SQL Symphony Concert 2017-12-20
# 10910      28582      1143  SQL Symphony Concert 2017-12-15
# 13719      81526      1143  SQL Symphony Concert 2017-12-02
# 13745      24397      1143  SQL Symphony Concert 2017-12-08
# 14312      11173      1143  SQL Symphony Concert 2017-12-23
# 15305      79312      1143  SQL Symphony Concert 2017-12-03
# 15896      69325      1143  SQL Symphony Concert 2017-12-06
# 20001      24556      1143  SQL Symphony Concert 2017-12-07
# ...

# %% [markdown]
# มีสองคนที่เข้าร่วมงาน 3 ครั้งคือ 24556 ,99716

# %%
person_df[person_df['id'].isin([24556, 99716])]
# Out:
#          id              name  license_id  address_number address_street_name  \
# 1587  24556       Bryan Pardo      101191             703          Machine Ln
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 1587  816663882
# 9985  987756388

# %%
driver_license_df[driver_license_df['id'].isin([101191, 202298	])]
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model
# 1105   Model S
